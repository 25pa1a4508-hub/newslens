# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4508-hub/newslens/blob/main/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# strings in python
a = input()
b=a.split()
print(b)
c=" ".join(b)
print(c)
# Out:
# thank you
# ['thank', 'you']
# thank you

# %%
#strings in python
a = "hello india"
b=a.split()
print(b)
c = " ".join(b)
print(c)
print(a.upper())
A = "vara"
print(A.upper())
B = "PAVANI"
print(B.lower())
print(B.count("A"))
print(len(A))
print(A.find("r"))
H = " bahubali epic "
print(H)
print(H.strip())
# Out:
# ['hello', 'india']
# hello india
# HELLO INDIA
# VARA
# pavani
# 2
# 4
# 2
#  bahubali epic
# bahubali epic
